# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
import time
from datetime import datetime

#import the api key
from config import weather_api_key

# %%
#create a set of random latitude and longitude combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities
cities = []

#identify the nearest city for each latitude and longitude combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
#print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %%
#starting url for weather map api call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_description = city_weather["weather"][0]["description"]
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                             "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 1 | general roca
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | te anau
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | ginir
# Processing Record 7 of Set 1 | poya
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | nicoya
# Processing Record 10 of Set 1 | cherskiy
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | kupang
# Processing Record 14 of Set 1 | san patricio
# Processing Record 15 of Set 1 | tete
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | khalkhal
# Processing Record 18 of Set 1 | college
# Processing Record 19 of Set 1 | grand gaube
# Processing Record 20 of Set 1 | pipri
# Processing Record 21 of Set 1 | carman
# Processing Record 22 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | chahal
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | ixtapa
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | lucea
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | yulara
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | west wendover
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | rio tercero
# Processing Record 37 of Set 1 | bonavista
# Processing Record 38 of Set 1 | grindavik
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | stephenville
# Processing Record 41 of Set 1 | qurayyat
# Processing Record 42 of Set 1 | saint george
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | lithakia
# Processing Record 46 of Set 1 | french harbor
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | conceicao do araguaia
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | pasni
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | vila franca do campo
# Processing Record 3 of Set 2 | liverpool
# Processing Record 4 of Set 2 | makasar
# Processing Record 5 of Set 2 | bonnyville
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | klaksvik
# Processing Record 8 of Set 2 | palmer
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 2 | vieques
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | sumbe
# Processing Record 15 of Set 2 | avera
# Processing Record 16 of Set 2 | kudahuvadhoo
# Processing Record 17 of Set 2 | sendafa
# Processing Record 18 of Set 2 | acajutla
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | kandri
# Processing Record 22 of Set 2 | salalah
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | akdepe
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | gifford
# Processing Record 30 of Set 2 | barkhan
# Processing Record 31 of Set 2 | svobodnyy
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | minuri
# Processing Record 35 of Set 2 | cidreira
# Processing Record 36 of Set 2 | magistralnyy
# Processing Record 37 of Set 2 | geraldton
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | mamakan
# Processing Record 41 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 2 | atar
# Processing Record 43 of Set 2 | fengrun
# Processing Record 44 of Set 2 | cap malheureux
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | tamiahua
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | whitehorse
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | synya
# Processing Record 2 of Set 3 | sur
# Processing Record 3 of Set 3 | hovd
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | zlobin
# Processing Record 7 of Set 3 | antalaha
# Processing Record 8 of Set 3 | haines junction
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | abulug
# Processing Record 11 of Set 3 | carballo
# Processing Record 12 of Set 3 | mataura
# Processing Record 13 of Set 3 | tautira
# Processing Record 14 of Set 3 | nome
# Processing Record 15 of Set 3 | namibe
# Processing Record 16 of Set 3 | ashtabula
# Processing Record 17 of Set 3 | hamilton
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | tyulgan
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | nikolskoye
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | verkhnevilyuysk
# Processing Record 24 of Set 3 | campohermoso
# Processing Record 25 of Set 3 | tekeli
# Processing Record 26 of Set 3 | vegueta
# Processing Record 27 of Set 3 | banda aceh
# Processing Record 28 of Set 3 | peremyshlyany
# Processing Record 29 of Set 3 | sal rei
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | nalut
# Processing Record 32 of Set 3 | qaqortoq
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | ostrovnoy
# Processing Record 35 of Set 3 | ust-maya
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 38 of Set 3 | pishva
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 3 | seoul
# Processing Record 43 of Set 3 | coquimbo
# Processing Record 44 of Set 3 | saint anthony
# Processing Record 45 of Set 3 | tarragona
# Processing Record 46 of Set 3 | natal
# Processing Record 47 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 3 | gloversville
# Processing Record 49 of Set 3 | weligama
# Processing Record 50 of Set 3 | nogliki
# Processing Record 1 of Set 4 | guanhaes
# Processing Record 2 of Set 4 | trairi
# Processing Record 3 of Set 4 | duzce
# Processing Record 4 of Set 4 | concepcion del oro
# Processing Record 5 of Set 4 | kahului
# Processing Record 6 of Set 4 | nantucket
# Processing Record 7 of Set 4 | sabaudia
# Processing Record 8 of Set 4 | cholan
# City not found. Skipping...
# Processing Record 9 of Set 4 | ponta delgada
# Processing Record 10 of Set 4 | alamogordo
# Processing Record 11 of Set 4 | mestia
# Processing Record 12 of Set 4 | thompson
# Processing Record 13 of Set 4 | norman wells
# Processing Record 14 of Set 4 | bosaso
# Processing Record 15 of Set 4 | flinders
# Processing Record 16 of Set 4 | dzaoudzi
# Processing Record 17 of Set 4 | berdigestyakh
# Processing Record 18 of Set 4 | tonekabon
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | olafsvik
# Processing Record 21 of Set 4 | ngunguru
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | mauguio
# Processing Record 24 of Set 4 | hobyo
# Processing Record 25 of Set 4 | izhma
# Processing Record 26 of Set 4 | pochutla
# Processing Record 27 of Set 4 | baruun-urt
# Processing Record 28 of Set 4 | saint-pierre
# Processing Record 29 of Set 4 | gaoua
# Processing Record 30 of Set 4 | gushikawa
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | setermoen
# Processing Record 33 of Set 4 | chaozhou
# Processing Record 34 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 4 | cape town
# Processing Record 36 of Set 4 | waipawa
# Processing Record 37 of Set 4 | mandalgovi
# Processing Record 38 of Set 4 | dnestrovsc
# Processing Record 39 of Set 4 | juan lacaze
# Processing Record 40 of Set 4 | kumi
# Processing Record 41 of Set 4 | ahtopol
# Processing Record 42 of Set 4 | pyinmana
# Processing Record 43 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 4 | chokurdakh
# Processing Record 46 of Set 4 | taganak
# Processing Record 47 of Set 4 | airai
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | innisfail
# Processing Record 50 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 5 | hamamatsu
# Processing Record 2 of Set 5 | dongsheng
# Processing Record 3 of Set 5 | ornskoldsvik
# Processing Record 4 of Set 5 | montevideo
# Processing Record 5 of Set 5 | constantine
# Processing Record 6 of Set 5 | mangan
# Processing Record 7 of Set 5 | kruisfontein
# Processing Record 8 of Set 5 | winnemucca
# Processing Record 9 of Set 5 | port hedland
# Processing Record 10 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 5 | inhambane
# Processing Record 12 of Set 5 | vrangel
# Processing Record 13 of Set 5 | manicore
# Processing Record 14 of Set 5 | satipo
# Processing Record 15 of Set 5 | farafangana
# Processing Record 16 of Set 5 | marawi
# Processing Record 17 of Set 5 | kalmunai
# Processing Record 18 of Set 5 | broken hill
# Processing Record 19 of Set 5 | toma
# Processing Record 20 of Set 5 | benguela
# Processing Record 21 of Set 5 | corinth
# Processing Record 22 of Set 5 | fort nelson
# Processing Record 23 of Set 5 | mitsamiouli
# Processing Record 24 of Set 5 | kedrovyy
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | cabedelo
# Processing Record 27 of Set 5 | fortuna
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | san luis rio colorado
# Processing Record 30 of Set 5 | adrar
# Processing Record 31 of Set 5 | san policarpo
# Processing Record 32 of Set 5 | lompoc
# Processing Record 33 of Set 5 | labytnangi
# Processing Record 34 of Set 5 | brae
# Processing Record 35 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 36 of Set 5 | challans
# Processing Record 37 of Set 5 | abu dhabi
# Processing Record 38 of Set 5 | vanavara
# Processing Record 39 of Set 5 | colombo
# Processing Record 40 of Set 5 | arica
# Processing Record 41 of Set 5 | santa maria
# Processing Record 42 of Set 5 | kasempa
# Processing Record 43 of Set 5 | half moon bay
# Processing Record 44 of Set 5 | tanabe
# Processing Record 45 of Set 5 | upernavik
# Processing Record 46 of Set 5 | pimentel
# Processing Record 47 of Set 5 | bluff
# Processing Record 48 of Set 5 | rocha
# Processing Record 49 of Set 5 | araouane
# Processing Record 50 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 6 | esmeralda
# Processing Record 2 of Set 6 | leh
# Processing Record 3 of Set 6 | simpang
# Processing Record 4 of Set 6 | yeppoon
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 6 | jiuquan
# Processing Record 9 of Set 6 | codrington
# Processing Record 10 of Set 6 | nenjiang
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | bonfim
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 6 | tiksi
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | semey
# Processing Record 18 of Set 6 | sept-iles
# Processing Record 19 of Set 6 | custoias
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | kabanjahe
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | kampot
# Processing Record 24 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 6 | ballina
# Processing Record 26 of Set 6 | lakselv
# Processing Record 27 of Set 6 | voh
# Processing Record 28 of Set 6 | srednekolymsk
# Processing Record 29 of Set 6 | aykhal
# Processing Record 30 of Set 6 | talaya
# Processing Record 31 of Set 6 | tuatapere
# Processing Record 32 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 6 | harper
# Processing Record 34 of Set 6 | yatou
# Processing Record 35 of Set 6 | mayor pablo lagerenza
# Processing Record 36 of Set 6 | lianzhou
# Processing Record 37 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 38 of Set 6 | altamira
# Processing Record 39 of Set 6 | bousse
# Processing Record 40 of Set 6 | aranda de duero
# Processing Record 41 of Set 6 | makung
# City not found. Skipping...
# Processing Record 42 of Set 6 | herouville-saint-clair
# Processing Record 43 of Set 6 | ozernovskiy
# Processing Record 44 of Set 6 | saint-philippe
# Processing Record 45 of Set 6 | labuhan
# Processing Record 46 of Set 6 | cabo san lucas
# Processing Record 47 of Set 6 | beauchamps
# Processing Record 48 of Set 6 | tucuman
# Processing Record 49 of Set 6 | kapenguria
# Processing Record 50 of Set 6 | katsuura
# Processing Record 1 of Set 7 | hambantota
# Processing Record 2 of Set 7 | victoria
# Processing Record 3 of Set 7 | penalva
# Processing Record 4 of Set 7 | hay river
# Processing Record 5 of Set 7 | ondjiva
# Processing Record 6 of Set 7 | sangar
# Processing Record 7 of Set 7 | bilma
# Processing Record 8 of Set 7 | zhaoqing
# Processing Record 9 of Set 7 | mormugao
# Processing Record 10 of Set 7 | bahia honda
# Processing Record 11 of Set 7 | mbigou
# Processing Record 12 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | thinadhoo
# Processing Record 15 of Set 7 | sao paulo de olivenca
# Processing Record 16 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 7 | imeni poliny osipenko
# Processing Record 18 of Set 7 | nhulunbuy
# Processing Record 19 of Set 7 | hami
# Processing Record 20 of Set 7 | kuryk
# Processing Record 21 of Set 7 | ruteng
# Processing Record 22 of Set 7 | mpulungu
# Processing Record 23 of Set 7 | les cayes
# Processing Record 24 of Set 7 | kodiak
# Processing Record 25 of Set 7 | nikki
# Processing Record 26 of Set 7 | mujiayingzi
# Processing Record 27 of Set 7 | vanimo
# Processing Record 28 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 7 | salinas
# Processing Record 30 of Set 7 | los llanos de aridane
# Processing Record 31 of Set 7 | nizhniy kuranakh
# Processing Record 32 of Set 7 | konstancin-jeziorna
# Processing Record 33 of Set 7 | egvekinot
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | muros
# Processing Record 36 of Set 7 | clyde river
# Processing Record 37 of Set 7 | toowoomba
# Processing Record 38 of Set 7 | veraval
# Processing Record 39 of Set 7 | saint-denis
# Processing Record 40 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 7 | kununurra
# Processing Record 42 of Set 7 | krasnoarmeyskiy
# Processing Record 43 of Set 7 | ellensburg
# Processing Record 44 of Set 7 | bontang
# Processing Record 45 of Set 7 | east london
# Processing Record 46 of Set 7 | tura
# Processing Record 47 of Set 7 | lasa
# Processing Record 48 of Set 7 | phalodi
# Processing Record 49 of Set 7 | laguna
# Processing Record 50 of Set 7 | taoudenni
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | mahebourg
# Processing Record 3 of Set 8 | shieli
# Processing Record 4 of Set 8 | sao filipe
# Processing Record 5 of Set 8 | tubuala
# Processing Record 6 of Set 8 | gazanjyk
# Processing Record 7 of Set 8 | bathsheba
# Processing Record 8 of Set 8 | bilibino
# Processing Record 9 of Set 8 | yaviza
# Processing Record 10 of Set 8 | dalbandin
# Processing Record 11 of Set 8 | porto walter
# Processing Record 12 of Set 8 | coahuayana
# Processing Record 13 of Set 8 | gingoog
# Processing Record 14 of Set 8 | huai mek
# Processing Record 15 of Set 8 | owando
# Processing Record 16 of Set 8 | buala
# Processing Record 17 of Set 8 | bagdarin
# Processing Record 18 of Set 8 | guerrero negro
# Processing Record 19 of Set 8 | port-gentil
# Processing Record 20 of Set 8 | ulaangom
# Processing Record 21 of Set 8 | mehamn
# Processing Record 22 of Set 8 | lubango
# Processing Record 23 of Set 8 | wajir
# Processing Record 24 of Set 8 | hithadhoo
# Processing Record 25 of Set 8 | sinnamary
# Processing Record 26 of Set 8 | aklavik
# Processing Record 27 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 8 | comodoro rivadavia
# Processing Record 29 of Set 8 | ilulissat
# Processing Record 30 of Set 8 | cangucu
# Processing Record 31 of Set 8 | dali
# Processing Record 32 of Set 8 | vaitape
# Processing Record 33 of Set 8 | ukiah
# Processing Record 34 of Set 8 | petropavl
# Processing Record 35 of Set 8 | camopi
# Processing Record 36 of Set 8 | chermoz
# Processing Record 37 of Set 8 | vila velha
# Processing Record 38 of Set 8 | chippewa falls
# Processing Record 39 of Set 8 | southbridge
# Processing Record 40 of Set 8 | talnakh
# Processing Record 41 of Set 8 | rudnyy
# Processing Record 42 of Set 8 | iralaya
# Processing Record 43 of Set 8 | otta
# Processing Record 44 of Set 8 | sorland
# Processing Record 45 of Set 8 | asilah
# Processing Record 46 of Set 8 | kidal
# Processing Record 47 of Set 8 | sibenik
# Processing Record 48 of Set 8 | leningradskiy
# Processing Record 49 of Set 8 | coronado
# Processing Record 50 of Set 8 | udachnyy
# Processing Record 1 of Set 9 | tuktoyaktuk
# Processing Record 2 of Set 9 | qinzhou
# Processing Record 3 of Set 9 | nishihara
# Processing Record 4 of Set 9 | ilabaya
# Processing Record 5 of Set 9 | alekseyevsk
# Processing Record 6 of Set 9 | oranjestad
# Processing Record 7 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 9 | kashan
# Processing Record 9 of Set 9 | luan
# Processing Record 10 of Set 9 | marsa matruh
# Processing Record 11 of Set 9 | olinda
# Processing Record 12 of Set 9 | matara
# Processing Record 13 of Set 9 | kysyl-syr
# Processing Record 14 of Set 9 | koslan
# Processing Record 15 of Set 9 | whitianga
# Processing Record 16 of Set 9 | vagay
# Processing Record 17 of Set 9 | balakhninskiy
# Processing Record 18 of Set 9 | kosikha
# Processing Record 19 of Set 9 | zabol
# Processing Record 20 of Set 9 | willowmore
# Processing Record 21 of Set 9 | eureka
# Processing Record 22 of Set 9 | narsaq
# Processing Record 23 of Set 9 | sistranda
# Processing Record 24 of Set 9 | eirunepe
# Processing Record 25 of Set 9 | khatanga
# Processing Record 26 of Set 9 | touros
# Processing Record 27 of Set 9 | klyuchi
# Processing Record 28 of Set 9 | tanga
# Processing Record 29 of Set 9 | guljanci
# City not found. Skipping...
# Processing Record 30 of Set 9 | praya
# Processing Record 31 of Set 9 | phnum penh
# City not found. Skipping...
# Processing Record 32 of Set 9 | dubna
# Processing Record 33 of Set 9 | podyuga
# Processing Record 34 of Set 9 | bowen
# Processing Record 35 of Set 9 | agadez
# Processing Record 36 of Set 9 | matamoros
# Processing Record 37 of Set 9 | acala
# Processing Record 38 of Set 9 | san quintin
# Processing Record 39 of Set 9 | ormara
# Processing Record 40 of Set 9 | constitucion
# Processing Record 41 of Set 9 | manzhouli
# Processing Record 42 of Set 9 | uglegorsk
# Processing Record 43 of Set 9 | nanortalik
# Processing Record 44 of Set 9 | kaeo
# Processing Record 45 of Set 9 | khandyga
# Processing Record 46 of Set 9 | hammerfest
# Processing Record 47 of Set 9 | galabovo
# Processing Record 48 of Set 9 | areosa
# Processing Record 49 of Set 9 | margate
# Processing Record 50 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 10 | bani walid
# Processing Record 2 of Set 10 | paamiut
# Processing Record 3 of Set 10 | kavieng
# Processing Record 4 of Set 10 | bristol
# Processing Record 5 of Set 10 | vardo
# Processing Record 6 of Set 10 | alenquer
# Processing Record 7 of Set 10 | ahuimanu
# Processing Record 8 of Set 10 | havelock
# Processing Record 9 of Set 10 | axim
# Processing Record 10 of Set 10 | glyadyanskoye
# Processing Record 11 of Set 10 | coihaique
# Processing Record 12 of Set 10 | benha
# City not found. Skipping...
# Processing Record 13 of Set 10 | port hawkesbury
# Processing Record 14 of Set 10 | evensk
# Processing Record 15 of Set 10 | guymon
# Processing Record 16 of Set 10 | lebedinyy
# Processing Record 17 of Set 10 | tromso
# Processing Record 18 of Set 10 | storslett
# Processing Record 19 of Set 10 | olenegorsk
# Processing Record 20 of Set 10 | kulhudhuffushi
# Processing Record 21 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 10 | victor harbor
# Processing Record 23 of Set 10 | the valley
# Processing Record 24 of Set 10 | gari
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | fairbanks
# Processing Record 27 of Set 10 | rawson
# Processing Record 28 of Set 10 | aneho
# Processing Record 29 of Set 10 | auki
# Processing Record 30 of Set 10 | porto santo
# Processing Record 31 of Set 10 | hirara
# Processing Record 32 of Set 10 | abapo
# Processing Record 33 of Set 10 | itamaraca
# Processing Record 34 of Set 10 | anju
# Processing Record 35 of Set 10 | kolpashevo
# Processing Record 36 of Set 10 | surt
# Processing Record 37 of Set 10 | torzhok
# Processing Record 38 of Set 10 | rio gallegos
# Processing Record 39 of Set 10 | anadyr
# Processing Record 40 of Set 10 | houma
# Processing Record 41 of Set 10 | casa nova
# Processing Record 42 of Set 10 | camacha
# Processing Record 43 of Set 10 | puerto escondido
# Processing Record 44 of Set 10 | magadan
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | severomorsk
# Processing Record 47 of Set 10 | pisco
# Processing Record 48 of Set 10 | beringovskiy
# Processing Record 49 of Set 10 | salem
# Processing Record 50 of Set 10 | blackwater
# Processing Record 1 of Set 11 | santa fe
# Processing Record 2 of Set 11 | orlik
# Processing Record 3 of Set 11 | lagoa
# Processing Record 4 of Set 11 | contamana
# Processing Record 5 of Set 11 | hasaki
# Processing Record 6 of Set 11 | cavalcante
# Processing Record 7 of Set 11 | vostok
# Processing Record 8 of Set 11 | nau
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | ilyich
# Processing Record 11 of Set 11 | sacramento
# Processing Record 12 of Set 11 | moura
# Processing Record 13 of Set 11 | port moresby
# Processing Record 14 of Set 11 | belo oriente
# Processing Record 15 of Set 11 | cayenne
# Processing Record 16 of Set 11 | tungor
# Processing Record 17 of Set 11 | fort-shevchenko
# Processing Record 18 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 11 | korla
# Processing Record 20 of Set 11 | yumen
# Processing Record 21 of Set 11 | seymchan
# Processing Record 22 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 11 | orlovskiy
# Processing Record 24 of Set 11 | krasnoselkup
# Processing Record 25 of Set 11 | pacific grove
# Processing Record 26 of Set 11 | anyama
# Processing Record 27 of Set 11 | berlevag
# Processing Record 28 of Set 11 | do rud
# City not found. Skipping...
# Processing Record 29 of Set 11 | whitley bay
# Processing Record 30 of Set 11 | manokwari
# Processing Record 31 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 32 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 11 | denpasar
# Processing Record 34 of Set 11 | tecoanapa
# Processing Record 35 of Set 11 | inta
# Processing Record 36 of Set 11 | mapiri
# Processing Record 37 of Set 11 | yerbogachen
# Processing Record 38 of Set 11 | volchikha
# Processing Record 39 of Set 11 | salou
# Processing Record 40 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 11 | mount gambier
# Processing Record 42 of Set 11 | xichang
# Processing Record 43 of Set 11 | altona
# Processing Record 44 of Set 11 | ucluelet
# Processing Record 45 of Set 11 | puerto del rosario
# Processing Record 46 of Set 11 | fort saint james
# Processing Record 47 of Set 11 | bulawayo
# Processing Record 48 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 11 | broome
# Processing Record 50 of Set 11 | sergeyevka
# Processing Record 1 of Set 12 | solnechnyy
# Processing Record 2 of Set 12 | lazarev
# Processing Record 3 of Set 12 | mbanza-ngungu
# Processing Record 4 of Set 12 | kedgwick
# Processing Record 5 of Set 12 | saurimo
# Processing Record 6 of Set 12 | sarnia
# Processing Record 7 of Set 12 | sesheke
# Processing Record 8 of Set 12 | bratslav
# Processing Record 9 of Set 12 | kazerun
# Processing Record 10 of Set 12 | karasjok
# Processing Record 11 of Set 12 | powell river
# Processing Record 12 of Set 12 | ziro
# Processing Record 13 of Set 12 | badiraguato
# Processing Record 14 of Set 12 | hervey bay
# Processing Record 15 of Set 12 | misratah
# Processing Record 16 of Set 12 | murgab
# Processing Record 17 of Set 12 | vestmannaeyjar
# Processing Record 18 of Set 12 | jeremie
# Processing Record 19 of Set 12 | rosarito
# Processing Record 20 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 21 of Set 12 | lakhipur
# Processing Record 22 of Set 12 | oistins
# Processing Record 23 of Set 12 | elizabeth city
# Processing Record 24 of Set 12 | ugoofaaru
# Processing Record 25 of Set 12 | belton
# Processing Record 26 of Set 12 | east wenatchee bench
# Processing Record 27 of Set 12 | gamba
# Processing Record 28 of Set 12 | iracoubo
# Processing Record 29 of Set 12 | yar-sale
# Processing Record 30 of Set 12 | bambanglipuro
# Processing Record 31 of Set 12 | diego de almagro
# Processing Record 32 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 12 | kyaikkami
# Processing Record 34 of Set 12 | tigil
# Processing Record 35 of Set 12 | sao felix do xingu
# Processing Record 36 of Set 12 | kawalu
# Processing Record 37 of Set 12 | noumea
# Processing Record 38 of Set 12 | lumeje
# Processing Record 39 of Set 12 | gerash
# Processing Record 40 of Set 12 | pangnirtung
# Processing Record 41 of Set 12 | goundi
# Processing Record 42 of Set 12 | richards bay
# Processing Record 43 of Set 12 | florianopolis
# Processing Record 44 of Set 12 | komsomolskiy
# Processing Record 45 of Set 12 | ubinskoye
# Processing Record 46 of Set 12 | conde
# Processing Record 47 of Set 12 | kutum
# Processing Record 48 of Set 12 | mount isa
# Processing Record 49 of Set 12 | kiruna
# Processing Record 50 of Set 12 | tuy hoa
# Processing Record 1 of Set 13 | roebourne
# Processing Record 2 of Set 13 | jinka
# Processing Record 3 of Set 13 | bayanday
# Processing Record 4 of Set 13 | aquiraz
# Processing Record 5 of Set 13 | piryion
# City not found. Skipping...
# Processing Record 6 of Set 13 | walvis bay
# Processing Record 7 of Set 13 | youghal
# Processing Record 8 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 13 | toora-khem
# Processing Record 10 of Set 13 | manali
# Processing Record 11 of Set 13 | linkoping
# Processing Record 12 of Set 13 | lata
# Processing Record 13 of Set 13 | kulu
# Processing Record 14 of Set 13 | lorengau
# Processing Record 15 of Set 13 | honningsvag
# Processing Record 16 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 13 | saint-francois
# Processing Record 18 of Set 13 | takefu
# Processing Record 19 of Set 13 | rincon
# Processing Record 20 of Set 13 | huarmey
# Processing Record 21 of Set 13 | opuwo
# Processing Record 22 of Set 13 | rongcheng
# Processing Record 23 of Set 13 | oktyabrskiy
# Processing Record 24 of Set 13 | ilinge
# Processing Record 25 of Set 13 | zalantun
# Processing Record 26 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 27 of Set 13 | maisuru
# City not found. Skipping...
# Processing Record 28 of Set 13 | vulcan
# Processing Record 29 of Set 13 | kant
# Processing Record 30 of Set 13 | boguchany
# Processing Record 31 of Set 13 | tahoua
# Processing Record 32 of Set 13 | sao teotonio
# Processing Record 33 of Set 13 | mochudi
# Processing Record 34 of Set 13 | port pirie
# Processing Record 35 of Set 13 | parainen
# Processing Record 36 of Set 13 | port blair
# Processing Record 37 of Set 13 | kristinehamn
# Processing Record 38 of Set 13 | geilo
# Processing Record 39 of Set 13 | pauini
# Processing Record 40 of Set 13 | marzuq
# Processing Record 41 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 13 | sokoto
# Processing Record 43 of Set 13 | karpathos
# Processing Record 44 of Set 13 | chapais
# Processing Record 45 of Set 13 | acapulco
# Processing Record 46 of Set 13 | pingxiang
# Processing Record 47 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 48 of Set 13 | svetlyy
# Processing Record 49 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 50 of Set 13 | obo
# Processing Record 1 of Set 14 | byron bay
# Processing Record 2 of Set 14 | deputatskiy
# Processing Record 3 of Set 14 | pooler
# Processing Record 4 of Set 14 | amahai
# Processing Record 5 of Set 14 | maxixe
# Processing Record 6 of Set 14 | kloulklubed
# Processing Record 7 of Set 14 | graham
# Processing Record 8 of Set 14 | ayan
# Processing Record 9 of Set 14 | hohhot
# Processing Record 10 of Set 14 | amudat
# Processing Record 11 of Set 14 | luena
# Processing Record 12 of Set 14 | dudinka
# Processing Record 13 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 14 | gustavo diaz ordaz
# Processing Record 15 of Set 14 | gat
# Processing Record 16 of Set 14 | basqal
# Processing Record 17 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 14 | narok
# Processing Record 19 of Set 14 | qianan
# Processing Record 20 of Set 14 | dongfeng
# Processing Record 21 of Set 14 | bud
# Processing Record 22 of Set 14 | igrim
# Processing Record 23 of Set 14 | pyapon
# Processing Record 24 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 14 | menongue
# Processing Record 26 of Set 14 | pitimbu
# Processing Record 27 of Set 14 | brigantine
# Processing Record 28 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 29 of Set 14 | tiznit
# Processing Record 30 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 32 of Set 14 | saintes
# Processing Record 33 of Set 14 | entre rios
# Processing Record 34 of Set 14 | duz
# City not found. Skipping...
# Processing Record 35 of Set 14 | pizarro
# Processing Record 36 of Set 14 | hualmay
# Processing Record 37 of Set 14 | sitka
# Processing Record 38 of Set 14 | gelemso
# Processing Record 39 of Set 14 | meulaboh
# Processing Record 40 of Set 14 | shelburne
# Processing Record 41 of Set 14 | berezanka
# Processing Record 42 of Set 14 | uni
# Processing Record 43 of Set 14 | dabeiba
# Processing Record 44 of Set 14 | guhagar
# Processing Record 45 of Set 14 | namatanai
# Processing Record 46 of Set 14 | karratha
# Processing Record 47 of Set 14 | rosport
# Processing Record 48 of Set 14 | terrak
# Processing Record 49 of Set 14 | sungaipenuh
# Processing Record 50 of Set 14 | stelle
# Processing Record 1 of Set 15 | hinton
# Processing Record 2 of Set 15 | zhezkazgan
# Processing Record 3 of Set 15 | capaci
# Processing Record 4 of Set 15 | great yarmouth
# Processing Record 5 of Set 15 | north bend
# Processing Record 6 of Set 15 | pangody
# Processing Record 7 of Set 15 | tilichiki
# Processing Record 8 of Set 15 | whittlesea
# Processing Record 9 of Set 15 | kampene
# Processing Record 10 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 11 of Set 15 | kassala
# Processing Record 12 of Set 15 | kultuk
# Processing Record 13 of Set 15 | sao jose da coroa grande
# Processing Record 14 of Set 15 | kasongo-lunda
# Processing Record 15 of Set 15 | monrovia
# Processing Record 16 of Set 15 | saint-joseph
# Processing Record 17 of Set 15 | bondo
# Processing Record 18 of Set 15 | lar gerd
# City not found. Skipping...
# Processing Record 19 of Set 15 | dese
# Processing Record 20 of Set 15 | botro
# Processing Record 21 of Set 15 | griffith
# Processing Record 22 of Set 15 | west bay
# Processing Record 23 of Set 15 | kavaratti
# Processing Record 24 of Set 15 | doka
# Processing Record 25 of Set 15 | khromtau
# Processing Record 26 of Set 15 | togitsu
# Processing Record 27 of Set 15 | russell
# Processing Record 28 of Set 15 | alamos
# Processing Record 29 of Set 15 | camapua
# Processing Record 30 of Set 15 | bubaque
# Processing Record 31 of Set 15 | port lincoln
# Processing Record 32 of Set 15 | mumford
# Processing Record 33 of Set 15 | san rafael
# Processing Record 34 of Set 15 | taburao
# City not found. Skipping...
# Processing Record 35 of Set 15 | calabozo
# Processing Record 36 of Set 15 | dyurtyuli
# Processing Record 37 of Set 15 | ferrol
# Processing Record 38 of Set 15 | logan
# Processing Record 39 of Set 15 | merauke
# Processing Record 40 of Set 15 | yeniseysk
# Processing Record 41 of Set 15 | dinghai
# Processing Record 42 of Set 15 | lensk
# Processing Record 43 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 15 | itaborai
# Processing Record 45 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 15 | kouroussa
# Processing Record 47 of Set 15 | portland
# Processing Record 48 of Set 15 | encantado
# Processing Record 49 of Set 15 | muli
# Processing Record 50 of Set 15 | necochea
# Processing Record 1 of Set 16 | igbo ora
# Processing Record 2 of Set 16 | mata
# Processing Record 3 of Set 16 | la ronge
# Processing Record 4 of Set 16 | pokhara
# Processing Record 5 of Set 16 | salcedo
# Processing Record 6 of Set 16 | fare
# Processing Record 7 of Set 16 | bafoulabe
# Processing Record 8 of Set 16 | muzhi
# Processing Record 9 of Set 16 | mossendjo
# Processing Record 10 of Set 16 | port-cartier
# Processing Record 11 of Set 16 | nabire
# Processing Record 12 of Set 16 | paita
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  General Roca -39.0333  -67.5833     91.62        18           1
# 1         Vaini -21.2000 -175.2000     80.76        78          20
# 2       Te Anau -45.4167  167.7167     53.38        94         100
# 3        Albany  42.6001  -73.9662     40.86        71          55
# 4         Ginir   7.1333   40.7000     57.07        39           5
#
#    Wind Speed Country Current Description
# 0       13.56      AR           clear sky
# 1        2.30      TO          few clouds
# 2        5.19      NZ     overcast clouds
# 3        3.00      US       broken clouds
# 4        6.87      ET           clear sky

# %%
#reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

correct_city_data = city_data_df[new_column_order]

correct_city_data
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    General Roca      AR -39.0333  -67.5833     91.62        18           1
# 1           Vaini      TO -21.2000 -175.2000     80.76        78          20
# 2         Te Anau      NZ -45.4167  167.7167     53.38        94         100
# 3          Albany      US  42.6001  -73.9662     40.86        71          55
# 4           Ginir      ET   7.1333   40.7000     57.07        39           5
# ..            ...     ...      ...       ...       ...       ...         ...
# 688         Muzhi      RU  65.3667   64.6667      7.63        95         100
# 689     Mossendjo      CG  -2.9506   12.7261     70.65        97         100
# 690  Port-Cartier      CA  50.0334  -66.8654     37.62        76          52
# 691        Nabire      ID  -3.3667  135.4833     74.82        91          67
# 692         Paita      PE  -5.0892  -81.1144     73.96        78          99
#
#      Wind Speed Current Description
# 0         13.56           clear sky
# 1          2.30          few clouds
# 2          5.19     overcast clouds
# 3          3.00       broken clouds
# 4          6.87           clear sky
# ..          ...                 ...
# 688       12.48          light snow
# 689        0.98          light rain
# 690       11.99       broken clouds
# 691        3.15       broken clouds
# 692       15.26     overcast clouds
#
# [693 rows x 9 columns]

# %%
#create the output file (CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

#export the city_data into a csv
correct_city_data.to_csv(output_data_file, index_label="City_ID")
